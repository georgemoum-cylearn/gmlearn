# %% [markdown]
# <a href="https://colab.research.google.com/github/georgemoum-cylearn/gmlearn/blob/main/dga_domain_csv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#εγκατάσταση πακέτου pycaret (https://pycaret.org/)
# !pip install pycaret
#***ΠΡΟΣΟΧΗ*** μετά την εγκατάσταση χρειάζεται restart το session
#***θα σας ζητηθεί επανεκκίνηση με σχετικό κόκκινο μήνυμα μετά την ολοκλήρωση της εγκατάστασης
#***Πατήστε το κουμπί RESTART SESSION στο σχετικό μήνυμα

# %%
import sys
print(f"Current Python version: {sys.version_info.major}.{sys.version_info.minor}.{sys.version_info.micro}")
# Out:
# Current Python version: 3.11.13

# %%
#εισαγωγή βιβλιοθηκών - πακέτων
import pycaret
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pycaret.classification import *

# %%
#εισαγωγή του συνόλου δεδομένων
url = 'https://raw.githubusercontent.com/kdemertzis/EKPA/main/Data/dga_domain.csv'
df = pd.read_csv(url)
#έλεγχος σχήματος συνόλου δεδομένων
print(df.shape)
# Out:
# (117588, 6)

# %%
#ανακάτεμα των δεδομένων
df = df.sample(frac = 1)
print(df.head())
# Out:
#         length   entropy   alexa_grams   word_grams      diff    class
# 113422      36  3.805497     11.939435    17.046190 -5.106755      dga
# 61448        9  2.503258     21.016309    25.987573 -4.971264    legit
# 26243        7  2.521641     16.793746    24.857487 -8.063741    legit
# 39082        5  1.921928      1.819544     1.986772 -0.167228  suspect
# 9339        12  3.251629     44.151322    46.835789 -2.684467    legit

# %%
from pycaret.classification import setup, compare_models

# Εκτύπωση των ονομάτων των στηλών για να ελέγξετε την ακριβή ονομασία της στήλης 'class'
print(df.columns)

# Αφαίρεση κενών από τα ονόματα των στηλών
df.columns = df.columns.str.strip()

# Συνεχίστε με την ρύθμιση του PyCaret
clf = setup(data = df, target = 'class', session_id = 123)
best = compare_models(cross_validation=False, n_select = 1)
# %load_ext tensorboard
# Out:
# Index(['length', ' entropy', ' alexa_grams', ' word_grams', ' diff', ' class'], dtype='object')
# <style type="text/css">
# #T_ced1b_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ced1b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ced1b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ced1b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ced1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ced1b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ced1b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ced1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ced1b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ced1b_row1_col1" class="data row1 col1" >class</td>
#     </tr>
# ...

# %%
#αναφορά των υπερπαραμέτρων του μοντέλου με την υψηλότερη απόδοση
try:
    print(best)
except NameError:
    print("Error: The variable 'best' is not defined. Please ensure all previous cells were run successfully.")
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
#μέτρα αξιολόγησης του μοντέλου με την υψηλότερη απόδοση
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
